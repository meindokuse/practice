# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in .\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in .\.venv\lib\site-packages (from easyocr) (2.7.1)
# Requirement already satisfied: torchvision>=0.5 in .\.venv\lib\site-packages (from easyocr) (0.22.1)
# Requirement already satisfied: opencv-python-headless in .\.venv\lib\site-packages (from easyocr) (4.11.0.86)
# Requirement already satisfied: scipy in .\.venv\lib\site-packages (from easyocr) (1.16.0)
# Requirement already satisfied: numpy in .\.venv\lib\site-packages (from easyocr) (2.3.1)
# Requirement already satisfied: Pillow in .\.venv\lib\site-packages (from easyocr) (11.3.0)
# Requirement already satisfied: scikit-image in .\.venv\lib\site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in .\.venv\lib\site-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in .\.venv\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in .\.venv\lib\site-packages (from easyocr) (2.1.1)
# Requirement already satisfied: pyclipper in .\.venv\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in .\.venv\lib\site-packages (from easyocr) (1.11.1.4)
# Requirement already satisfied: filelock in .\.venv\lib\site-packages (from torch->easyocr) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\.venv\lib\site-packages (from torch->easyocr) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in .\.venv\lib\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx in .\.venv\lib\site-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in .\.venv\lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in .\.venv\lib\site-packages (from torch->easyocr) (2025.5.1)
# Requirement already satisfied: setuptools in .\.venv\lib\site-packages (from torch->easyocr) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\.venv\lib\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in .\.venv\lib\site-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in .\.venv\lib\site-packages (from scikit-image->easyocr) (2025.6.11)
# Requirement already satisfied: packaging>=21 in .\.venv\lib\site-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in .\.venv\lib\site-packages (from scikit-image->easyocr) (0.4)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in .\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in .\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in .\.venv\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in .\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in .\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# %%
image_path = 'test3.jpg'
image = cv2.imread(image_path)

# %%
reader = easyocr.Reader(['ru'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
results = reader.readtext(image)

# %%
for (bbox, text, prob) in results:
    print(f"Текст: {text} (Точность: {prob:.2f})")
    
    top_left = tuple(map(int, bbox[0]))
    bottom_right = tuple(map(int, bbox[2]))
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)
    
    cv2.putText(image, text, top_left, cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)
# Out:
# Текст: Желою (Точность: 0.90)
# Текст: ТрофВомония (Точность: 0.42)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
